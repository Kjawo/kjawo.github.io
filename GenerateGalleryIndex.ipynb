# %%
using System.IO;

var output = $@"---
layout: page
title: ""Gallery""
description: ""Konrad Jaworski""
active: gallery
header-img: ""gallery/archive/g01/bg001.jpg""
album-title: """"
images:
 - image_path: /gallery/archive/g01/bg001.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg002.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg003.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg004.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg005.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg006.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg007.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg008.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg009.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg010.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg011.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg012.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg013.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg014.jpg
   caption: 
   copyright: © Konrad Jaworski
 - image_path: /gallery/archive/g01/bg015.jpg
   caption: 
   copyright: © Konrad Jaworski
";


DirectoryInfo info = new DirectoryInfo(@"C:\Users\kjawo\Documents\repo\kjawogithubio\gallery\archive\g01");
FileInfo[] files = info.GetFiles().OrderBy(p => p.CreationTime).ToArray();
var index = 15;
foreach(var file in files)
{ 
  var fileNumber = 100;
  try{
    fileNumber = int.Parse(string.Join("", file.Name.TakeLast(7).SkipLast(4)));
    }catch
    {}

    if(fileNumber <= 15)
    {
        continue;
    }

   output += $@" - image_path: /gallery/archive/g01/{file.Name}
   caption: 
   copyright: © Konrad Jaworski
";

  index++;
}
output += $@"---

<html class=""no-js"" lang=""en"">
<head>
	<meta content=""charset=utf-8"">
</head>

    <body>
 
	<section id=""content"" role=""main"">
		<div class=""wrapper"">
	<br><br>
			<h2>{{{{page.album-title}}}}</h2>


			<!-- Gallery __-->
			<div class=""gallery masonry-gallery"">
		
{{% for image in page.images %}}  		

				<figure class=""gallery-item"">
					<header class='gallery-icon'>

<a href=""{{{{ site.url }}}}{{{{ site.baseurl }}}}{{{{ image.image_path }}}}"" class=""popup""  title=""{{{{ image.caption }}}}"" data-caption=""{{{{ image.copyright }}}}"">
<img src=""{{{{ site.url }}}}{{{{ site.baseurl }}}}{{{{ image.image_path }}}}""></a>
						
					</header>	
					<figcaption class='gallery-caption'>
						<div class=""entry-summary"" id=""{{{{ image.caption }}}}"">
							<h3>{{{{image.caption}}}}</h3>
							<p>{{{{image.copyright}}}}</p>
						</div>
					</figcaption>
				</figure>
				
{{% endfor %}}

			</div>

		</div><!-- END .wrapper -->
	</section>

<!-- jQuery -->    

<script type=""text/javascript"" src=""//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js""></script>
<!-- include image popups -->
<script src=""{{{{ site.baseurl }}}}/js/jquery.magnific-popup.js""></script>

<script type=""text/javascript"">
      $(document).ready(function($) {{
        $('a.popup').magnificPopup({{
         type: 'image',
	  gallery:{{
         enabled:true,
         navigateByImgClick: true,
         preload: [0,1] // Will preload 0 - before current, and 1 after the current image
       }},
image: {{
      titleSrc: function(item) {{
              return item.el.attr('title') + '&nbsp;' + item.el.attr('data-caption');
            }}
        }}
          // other options
      }});
}});
    </script>

<script src=""{{{{ site.baseurl }}}}/js/retina.min.js""></script>
<!-- include Masonry -->
<script src=""{{{{ site.baseurl }}}}/js/isotope.pkgd.min.js""></script> 
<!-- include mousewheel plugins -->
<script src=""{{{{ site.baseurl }}}}/js/jquery.mousewheel.min.js""></script>
<!-- include carousel plugins -->
<script src=""{{{{ site.baseurl}}}}/js/jquery.tinycarousel.min.js""></script>
<!-- include svg line drawing plugin -->
<script src=""{{{{ site.baseurl }}}}/js/jquery.lazylinepainter.min.js""></script>
<!-- include custom script -->
<script src=""{{{{ site.baseurl }}}}/js/scripts.js""></script>
<!-- Modernizr -->
 <script src=""{{{{ site.baseurl }}}}/js/modernizr.js""></script>

    
</body></html>";

File.WriteAllText(@"C:\Users\kjawo\Documents\repo\kjawogithubio\gallery\gallery01\index.html", output);

# %%
using System.IO;

var output = $@"---
layout: page
title: ""Architecure photography""
description: ""Konrad Jaworski""
active: gallery
header-img: ""gallery/archive/g01/bg001.jpg""
album-title: """"
images:
";


DirectoryInfo info = new DirectoryInfo(@"C:\Users\kjawo\Documents\repo\kjawogithubio\gallery\archive\g02");
FileInfo[] files = info.GetFiles().OrderBy(p => p.Name).ToArray();
foreach(var file in files)
{ 

   output += $@" - image_path: /gallery/archive/g02/{file.Name}
   caption: 
   copyright: © Konrad Jaworski
";

}
output += $@"---

<html class=""no-js"" lang=""en"">
<head>
	<meta content=""charset=utf-8"">
</head>

    <body>
 
	<section id=""content"" role=""main"">
		<div class=""wrapper"">
	<br><br>
			<h2>{{{{page.album-title}}}}</h2>


			<!-- Gallery __-->
			<div class=""gallery masonry-gallery"">
		
{{% for image in page.images %}}  		

				<figure class=""gallery-item"">
					<header class='gallery-icon'>

<a href=""{{{{ site.url }}}}{{{{ site.baseurl }}}}{{{{ image.image_path }}}}"" class=""popup""  title=""{{{{ image.caption }}}}"" data-caption=""{{{{ image.copyright }}}}"">
<img src=""{{{{ site.url }}}}{{{{ site.baseurl }}}}{{{{ image.image_path }}}}""></a>
						
					</header>	
					<figcaption class='gallery-caption'>
						<div class=""entry-summary"" id=""{{{{ image.caption }}}}"">
							<h3>{{{{image.caption}}}}</h3>
							<p>{{{{image.copyright}}}}</p>
						</div>
					</figcaption>
				</figure>
				
{{% endfor %}}

			</div>

		</div><!-- END .wrapper -->
	</section>

<!-- jQuery -->    

<script type=""text/javascript"" src=""//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js""></script>
<!-- include image popups -->
<script src=""{{{{ site.baseurl }}}}/js/jquery.magnific-popup.js""></script>

<script type=""text/javascript"">
      $(document).ready(function($) {{
        $('a.popup').magnificPopup({{
         type: 'image',
	  gallery:{{
         enabled:true,
         navigateByImgClick: true,
         preload: [0,1] // Will preload 0 - before current, and 1 after the current image
       }},
image: {{
      titleSrc: function(item) {{
              return item.el.attr('title') + '&nbsp;' + item.el.attr('data-caption');
            }}
        }}
          // other options
      }});
}});
    </script>

<script src=""{{{{ site.baseurl }}}}/js/retina.min.js""></script>
<!-- include Masonry -->
<script src=""{{{{ site.baseurl }}}}/js/isotope.pkgd.min.js""></script> 
<!-- include mousewheel plugins -->
<script src=""{{{{ site.baseurl }}}}/js/jquery.mousewheel.min.js""></script>
<!-- include carousel plugins -->
<script src=""{{{{ site.baseurl}}}}/js/jquery.tinycarousel.min.js""></script>
<!-- include svg line drawing plugin -->
<script src=""{{{{ site.baseurl }}}}/js/jquery.lazylinepainter.min.js""></script>
<!-- include custom script -->
<script src=""{{{{ site.baseurl }}}}/js/scripts.js""></script>
<!-- Modernizr -->
 <script src=""{{{{ site.baseurl }}}}/js/modernizr.js""></script>

    
</body></html>";

File.WriteAllText(@"C:\Users\kjawo\Documents\repo\kjawogithubio\gallery\gallery02\index.html", output);
